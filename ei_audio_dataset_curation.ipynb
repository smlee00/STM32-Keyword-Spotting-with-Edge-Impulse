# %% [markdown]
# # Keyword Spotting Dataset Curation
#
# [![Open In Colab <](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShawnHymel/ei-keyword-spotting/blob/master/ei-audio-dataset-curation.ipynb)
#
# Use this tool to download the Google Speech Commands Dataset, combine it with your own keywords, mix in some background noise, and upload the curated dataset to Edge Impulse. From there, you can train a neural network to classify spoken words and upload it to a microcontroller to perform real-time keyword spotting.
#
#  1. Upload samples of your own keyword (optional)
#  2. Adjust parameters in the Settings cell (you will need an [Edge Impulse](https://www.edgeimpulse.com/) account)
#  3. Run the rest of the cells! ('shift' + 'enter' on each cell)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Upload your own keyword samples
# You are welcome to use my [custom keyword dataset](https://github.com/ShawnHymel/custom-speech-commands-dataset), but note that it's limited and that I can't promise it will work well. If you want to use it, uncomment the `###Download custom dataset` cell below. You may also add your own recorded keywords to the extracted folder (`/content/custom_keywords`) to augment what's already there.
#
# If you'd rather upload your own custom keyword dataset, follow these instructions:
#
# On the left pane, in the file browser, create a directory structure containing space for your keyword audio samples. All samples for each keyword should be in a directory with that keyword's name.
#
# The audio samples should be `.wav` format, mono, and 1 second long. Bitrate and bitdepth should not matter. Samples shorter than 1 second will be padded with 0s, and samples longer than 1 second will be truncated to 1 second. The exact name of each `.wav` file does not matter, as they will be read, mixed with background noise, and saved to a separate file with an auto-generated name. Directory name does matter (it is used to determine the name of the class during neural network training).
#
# Right-click on each keyword directory and upload all of your samples. Your directory structor should look like the following:
#
# ```
# /
# |- content
# |--- custom_keywords
# |----- keyword_1
# |------- 000.wav
# |------- 001.wav
# |------- ...
# |----- keyword_2
# |------- 000.wav
# |------- 001.wav
# |------- ...
# |----- ...
# ```

# %%
### Update Node.js to the latest stable version
# !npm cache clean -f
# !npm install -g n
# !n stable
# Out:
# npm WARN using --force I sure hope you know what you are doing.
# /tools/node/bin/n -> /tools/node/lib/node_modules/n/bin/n
# + n@7.2.2
# added 1 package from 2 contributors in 0.322s
#
#
#    ╭────────────────────────────────────────────────────────────────╮
#    │                                                                │
#    │      New major version of npm available! 6.14.8 → 7.12.0       │
#    │   Changelog: https://github.com/npm/cli/releases/tag/v7.12.0   │
#    │               Run npm install -g npm to update!                │
#    │                                                                │
#    ╰────────────────────────────────────────────────────────────────╯
#
#   installing : node-v14.16.1
#        mkdir : /usr/local/n/versions/node/14.16.1
#        fetch : https://nodejs.org/dist/v14.16.1/node-v14.16.1-linux-x64.tar.xz
# ######################################################################## 100.0%
#    installed : v14.16.1 (with npm 6.14.12)
#
# Note: the node command changed location and the old location may be remembered in your current shell.
#          old : /tools/node/bin/node
#          new : /usr/local/bin/node
# To reset the command location hash either start a new shell, or execute PATH="$PATH"

# %%
### Install required packages and tools
# !python -m pip install soundfile
# !npm install -g --unsafe-perm edge-impulse-cli
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile) (2.20)
# npm WARN deprecated request-promise@4.2.6: request-promise has been deprecated because it extends the now deprecated request package, see https://github.com/request/request/issues/3142
# npm WARN deprecated request@2.88.2: request has been deprecated, see https://github.com/request/request/issues/3142
# npm WARN deprecated @zeit/dockerignore@0.0.5: "@zeit/dockerignore" is no longer maintained
# npm WARN deprecated har-validator@5.1.5: this library is no longer supported
# /usr/local/bin/edge-impulse-blocks -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/blocks.js
# /usr/local/bin/edge-impulse-uploader -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/uploader.js
# /usr/local/bin/edge-impulse-daemon -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/daemon.js
# /usr/local/bin/edge-impulse-data-forwarder -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/data-forwarder.js
# /usr/local/bin/edge-impulse-run-impulse -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/run-impulse.js
# /usr/local/bin/eta-flash-tool -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/eta-flash-tool/flashtool.js
# /usr/local/bin/himax-flash-tool -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/himax-flash-tool/flashtool.js
# /usr/local/bin/edge-impulse-framebuffer2jpg -> /usr/local/lib/node_modules/edge-impulse-cli/build/cli/framebuffer-to-jpg.js
#
# > @serialport/bindings@8.0.8 install /usr/local/lib/node_modules/edge-impulse-cli/node_modules/@serialport/bindings
# > prebuild-install --tag-prefix @serialport/bindings@ || node-gyp rebuild
#
# prebuild-install WARN install No prebuilt binaries found (target=14.16.1 runtime=node arch=x64 libc= platform=linux)
# make: Entering directory '/usr/local/lib/node_modules/edge-impulse-cli/node_modules/@serialport/bindings/build'
#   CXX(target) Release/obj.target/bindings/src/serialport.o
#   CXX(target) Release/obj.target/bindings/src/serialport_unix.o
# ../src/serialport_unix.cpp: In function ‘int setup(int, OpenBaton*)’:
# ../src/serialport_unix.cpp:166:5: warning: ‘%s’ directive output may be truncated writing up to 1023 bytes into a region of size 1005 [-Wformat-truncation=]
#  int setup(int fd, OpenBaton *data) {
#      ^~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from ../src/serialport.h:3,
#                  from ../src/serialport_unix.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:65:44: note: ‘__builtin___snprintf_chk’ output 20 or more bytes (assuming 1043) into a destination of size 1024
#         __bos (__s), __fmt, __va_arg_pack ());
#                                             ^
# ../src/serialport_unix.cpp: In function ‘void EIO_Open(uv_work_t*)’:
# ../src/serialport_unix.cpp:79:6: warning: ‘%s’ directive output may be truncated writing up to 1023 bytes into a region of size 1003 [-Wformat-truncation=]
#  void EIO_Open(uv_work_t* req) {
#       ^~~~~~~~
# In file included from /usr/include/stdio.h:862:0,
#                  from ../src/serialport.h:3,
#                  from ../src/serialport_unix.cpp:2:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:65:44: note: ‘__builtin___snprintf_chk’ output 22 or more bytes (assuming 1045) into a destination of size 1024
#         __bos (__s), __fmt, __va_arg_pack ());
#                                             ^
#   CXX(target) Release/obj.target/bindings/src/poller.o
#   CXX(target) Release/obj.target/bindings/src/serialport_linux.o
#   SOLINK_MODULE(target) Release/obj.target/bindings.node
#   COPY Release/bindings.node
# make: Leaving directory '/usr/local/lib/node_modules/edge-impulse-cli/node_modules/@serialport/bindings/build'
#
# > serialport@8.0.8 postinstall /usr/local/lib/node_modules/edge-impulse-cli/node_modules/serialport
# > node thank-you.js
#
# Thank you for using serialport!
# If you rely on this package, please consider supporting our open collective:
# > https://opencollective.com/serialport/donate
#
#
# + edge-impulse-cli@1.13.4
# added 296 packages from 235 contributors in 20.294s

# %%
### Settings (You probably do not need to change these)
BASE_DIR = "/content"
OUT_DIR = "keywords_curated"
GOOGLE_DATASET_FILENAME = "speech_commands_v0.02.tar.gz"
GOOGLE_DATASET_URL = "http://download.tensorflow.org/data/" + GOOGLE_DATASET_FILENAME
GOOGLE_DATASET_DIR = "google_speech_commands"
CUSTOM_KEYWORDS_FILENAME = "main.zip"
CUSTOM_KEYWORDS_URL = "https://github.com/ShawnHymel/custom-speech-commands-dataset/archive/" + CUSTOM_KEYWORDS_FILENAME
CUSTOM_KEYWORDS_DIR = "custom_keywords"
CUSTOM_KEYWORDS_REPO_NAME = "custom-speech-commands-dataset-main"
CURATION_SCRIPT = "dataset-curation.py"
CURATION_SCRIPT_URL = "https://raw.githubusercontent.com/smlee00/STM32-Keyword-Spotting-with-Edge-Impulse/master/" + CURATION_SCRIPT
UTILS_SCRIPT_URL = "https://raw.githubusercontent.com/smlee00/STM32-Keyword-Spotting-with-Edge-Impulse/master/utils.py"
NUM_SAMPLES = 1500    # Target number of samples to mix and send to Edge Impulse
WORD_VOL = 1.0        # Relative volume of word in output sample
BG_VOL = 0.1          # Relative volume of noise in output sample
SAMPLE_TIME = 1.0     # Time (seconds) of output sample
SAMPLE_RATE = 16000   # Sample rate (Hz) of output sample
BIT_DEPTH = "PCM_16"  # Options: [PCM_16, PCM_24, PCM_32, PCM_U8, FLOAT, DOUBLE]
BG_DIR = "_background_noise_"
TEST_RATIO = 0.2      # 20% reserved for test set, rest is for training
EI_INGEST_TEST_URL = "https://ingestion.edgeimpulse.com/api/test/data"
EI_INGEST_TRAIN_URL = "https://ingestion.edgeimpulse.com/api/training/data"

# %%
### Download Google Speech Commands Dataset
# !cd {BASE_DIR}
# !wget {GOOGLE_DATASET_URL}
# !mkdir {GOOGLE_DATASET_DIR}
# !echo "Extracting..."
# !tar xfz {GOOGLE_DATASET_FILENAME} -C {GOOGLE_DATASET_DIR}
# Out:
# --2021-05-08 07:23:37--  http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.99.128, 2607:f8b0:400e:c0c::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.99.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2428923189 (2.3G) [application/gzip]
# Saving to: ‘speech_commands_v0.02.tar.gz’
#
# speech_commands_v0. 100%[===================>]   2.26G  70.5MB/s    in 19s
#
# 2021-05-08 07:23:56 (122 MB/s) - ‘speech_commands_v0.02.tar.gz’ saved [2428923189/2428923189]
#
# Extracting...

# %%
### Pull out background noise directory
# !cd {BASE_DIR}
# !mv "{GOOGLE_DATASET_DIR}/{BG_DIR}" "{BG_DIR}"

# %%
### (Optional) Download custom dataset--uncomment the code in this cell if you want to use my custom datase

## Download, extract, and move dataset to separate directory
# !cd {BASE_DIR}
# !wget {CUSTOM_KEYWORDS_URL}
# !echo "Extracting..."
# !unzip -q {CUSTOM_KEYWORDS_FILENAME}
# !mv "{CUSTOM_KEYWORDS_REPO_NAME}/{CUSTOM_KEYWORDS_DIR}" "{CUSTOM_KEYWORDS_DIR}"

# %%
### User Settings (do change these)

# Location of your custom keyword samples (e.g. "/content/custom_keywords")
# Leave blank ("") for no custom keywords. set to the CUSTOM_KEYWORDS_DIR
# variable to use samples from my custom-speech-commands-dataset repo.
CUSTOM_DATASET_PATH = ""

# Edge Impulse > your_project > Dashboard > Keys
EI_API_KEY = "ei_8dc9b218b6553215681a1b9146f438d332fce4e3d8642d5b451b5545f187551d" 

# Comma separated words. Must match directory names (that contain samples).
TARGETS = "marvin, on, off, bed"

# %%
### Download curation and utils scripts
# !wget {CURATION_SCRIPT_URL}
# !wget {UTILS_SCRIPT_URL}

# %%
### Perform curation and mixing of samples with background noise
# !cd {BASE_DIR}
# !python {CURATION_SCRIPT} \
  -t "{TARGETS}" \
  -n {NUM_SAMPLES} \
  -w {WORD_VOL} \
  -g {BG_VOL} \
  -s {SAMPLE_TIME} \
  -r {SAMPLE_RATE} \
  -e {BIT_DEPTH} \
  -b "{BG_DIR}" \
  -o "{OUT_DIR}" \
  "{GOOGLE_DATASET_DIR}" \
  "{CUSTOM_DATASET_PATH}"
# Out:
# -----------------------------------------------------------------------
# Keyword Dataset Curation Tool
# v0.1
# -----------------------------------------------------------------------
# No directory named ''. Ignoring.
# Gathering random background noise snippets (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: marvin (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: on (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: off (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: bed (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# No directory named ''. Ignoring.
# Mixing: _unknown (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Done!

# %%
### Use CLI tool to send curated dataset to Edge Impulse

# !cd {BASE_DIR}

# Imports
import os
import random

# Seed with system time
random.seed()

# Go through each category in our curated dataset
for dir in os.listdir(OUT_DIR):
  
  # Create list of files for one category
  paths = []
  for filename in os.listdir(os.path.join(OUT_DIR, dir)):
    paths.append(os.path.join(OUT_DIR, dir, filename))

  # Shuffle and divide into test and training sets
  random.shuffle(paths)
  num_test_samples = int(TEST_RATIO * len(paths))
  test_paths = paths[:num_test_samples]
  train_paths = paths[num_test_samples:]

  # Create arugments list (as a string) for CLI call
  test_paths = ['"' + s + '"' for s in test_paths]
  test_paths = ' '.join(test_paths)
  train_paths = ['"' + s + '"' for s in train_paths]
  train_paths = ' '.join(train_paths)
  
  # Send test files to Edge Impulse
  # !edge-impulse-uploader \
    --category testing \
    --label {dir} \
    --api-key {EI_API_KEY} \
    --silent \
    {test_paths}

  # # Send training files to Edge Impulse
  # !edge-impulse-uploader \
    --category training \
    --label {dir} \
    --api-key {EI_API_KEY} \
    --silent \
    {train_paths}
# Out:
# Streaming output truncated to the last 5000 lines.
# [ 707/1200] Uploading keywords_curated/on/on.0018.wav OK (407 ms)
# [ 708/1200] Uploading keywords_curated/on/on.0379.wav OK (439 ms)
# [ 709/1200] Uploading keywords_curated/on/on.0295.wav OK (270 ms)
# [ 710/1200] Uploading keywords_curated/on/on.0803.wav OK (253 ms)
# [ 711/1200] Uploading keywords_curated/on/on.0096.wav OK (320 ms)
# [ 712/1200] Uploading keywords_curated/on/on.0039.wav OK (270 ms)
# [ 713/1200] Uploading keywords_curated/on/on.0118.wav OK (288 ms)
# [ 714/1200] Uploading keywords_curated/on/on.1318.wav OK (274 ms)
# [ 715/1200] Uploading keywords_curated/on/on.0800.wav OK (239 ms)
# [ 716/1200] Uploading keywords_curated/on/on.0616.wav OK (453 ms)
# [ 717/1200] Uploading keywords_curated/on/on.0137.wav OK (326 ms)
# [ 718/1200] Uploading keywords_curated/on/on.1175.wav OK (293 ms)
# [ 719/1200] Uploading keywords_curated/on/on.1012.wav OK (279 ms)
# [ 720/1200] Uploading keywords_curated/on/on.0417.wav OK (246 ms)
# [ 721/1200] Uploading keywords_curated/on/on.0533.wav OK (266 ms)
# [ 722/1200] Uploading keywords_curated/on/on.0697.wav OK (277 ms)
# [ 723/1200] Uploading keywords_curated/on/on.0434.wav OK (261 ms)
# [ 724/1200] Uploading keywords_curated/on/on.0943.wav OK (202 ms)
# [ 725/1200] Uploading keywords_curated/on/on.0592.wav OK (314 ms)
# [ 726/1200] Uploading keywords_curated/on/on.1242.wav OK (329 ms)
# [ 727/1200] Uploading keywords_curated/on/on.1264.wav OK (276 ms)
# [ 728/1200] Uploading keywords_curated/on/on.0254.wav OK (259 ms)
# [ 729/1200] Uploading keywords_curated/on/on.0241.wav OK (289 ms)
# [ 730/1200] Uploading keywords_curated/on/on.0818.wav OK (334 ms)
# [ 731/1200] Uploading keywords_curated/on/on.0751.wav OK (299 ms)
# [ 732/1200] Uploading keywords_curated/on/on.1082.wav OK (268 ms)
# [ 733/1200] Uploading keywords_curated/on/on.1098.wav OK (228 ms)
# [ 734/1200] Uploading keywords_curated/on/on.0283.wav OK (322 ms)
# [ 735/1200] Uploading keywords_curated/on/on.0330.wav OK (238 ms)
# [ 736/1200] Uploading keywords_curated/on/on.0978.wav OK (398 ms)
# [ 737/1200] Uploading keywords_curated/on/on.0594.wav OK (258 ms)
# [ 738/1200] Uploading keywords_curated/on/on.1383.wav OK (286 ms)
# [ 739/1200] Uploading keywords_curated/on/on.0868.wav OK (268 ms)
# [ 740/1200] Uploading keywords_curated/on/on.0060.wav OK (248 ms)
# [ 741/1200] Uploading keywords_curated/on/on.0549.wav OK (411 ms)
# [ 742/1200] Uploading keywords_curated/on/on.0024.wav OK (301 ms)
# [ 743/1200] Uploading keywords_curated/on/on.1258.wav OK (250 ms)
# [ 744/1200] Uploading keywords_curated/on/on.0291.wav OK (410 ms)
# [ 745/1200] Uploading keywords_curated/on/on.0979.wav OK (266 ms)
# [ 746/1200] Uploading keywords_curated/on/on.0189.wav OK (305 ms)
# [ 747/1200] Uploading keywords_curated/on/on.1278.wav OK (291 ms)
# [ 748/1200] Uploading keywords_curated/on/on.1087.wav OK (387 ms)
# [ 749/1200] Uploading keywords_curated/on/on.0918.wav OK (227 ms)
# [ 750/1200] Uploading keywords_curated/on/on.0758.wav OK (320 ms)
# [ 751/1200] Uploading keywords_curated/on/on.0808.wav OK (306 ms)
# [ 752/1200] Uploading keywords_curated/on/on.0158.wav OK (243 ms)
# [ 753/1200] Uploading keywords_curated/on/on.0963.wav OK (312 ms)
# [ 754/1200] Uploading keywords_curated/on/on.0993.wav OK (262 ms)
# [ 755/1200] Uploading keywords_curated/on/on.1358.wav OK (294 ms)
# [ 756/1200] Uploading keywords_curated/on/on.1029.wav OK (376 ms)
# [ 757/1200] Uploading keywords_curated/on/on.0539.wav OK (260 ms)
# [ 758/1200] Uploading keywords_curated/on/on.0609.wav OK (243 ms)
# [ 759/1200] Uploading keywords_curated/on/on.0153.wav OK (298 ms)
# [ 760/1200] Uploading keywords_curated/on/on.0861.wav OK (284 ms)
# [ 761/1200] Uploading keywords_curated/on/on.1372.wav OK (267 ms)
# [ 762/1200] Uploading keywords_curated/on/on.0696.wav OK (250 ms)
# [ 763/1200] Uploading keywords_curated/on/on.0607.wav OK (285 ms)
# [ 764/1200] Uploading keywords_curated/on/on.0510.wav OK (320 ms)
# [ 765/1200] Uploading keywords_curated/on/on.0585.wav OK (250 ms)
# [ 766/1200] Uploading keywords_curated/on/on.0367.wav OK (303 ms)
# [ 767/1200] Uploading keywords_curated/on/on.0774.wav OK (318 ms)
# [ 768/1200] Uploading keywords_curated/on/on.1026.wav OK (271 ms)
# [ 769/1200] Uploading keywords_curated/on/on.0889.wav OK (270 ms)
# [ 770/1200] Uploading keywords_curated/on/on.1080.wav OK (288 ms)
# [ 771/1200] Uploading keywords_curated/on/on.1071.wav OK (256 ms)
# [ 772/1200] Uploading keywords_curated/on/on.0867.wav OK (428 ms)
# [ 773/1200] Uploading keywords_curated/on/on.0895.wav OK (287 ms)
# [ 774/1200] Uploading keywords_curated/on/on.0275.wav OK (270 ms)
# [ 775/1200] Uploading keywords_curated/on/on.1013.wav OK (237 ms)
# [ 776/1200] Uploading keywords_curated/on/on.0520.wav OK (300 ms)
# [ 777/1200] Uploading keywords_curated/on/on.1171.wav OK (258 ms)
# [ 778/1200] Uploading keywords_curated/on/on.0882.wav OK (258 ms)
# [ 779/1200] Uploading keywords_curated/on/on.0077.wav OK (400 ms)
# [ 780/1200] Uploading keywords_curated/on/on.1385.wav OK (272 ms)
# [ 781/1200] Uploading keywords_curated/on/on.0437.wav OK (367 ms)
# [ 782/1200] Uploading keywords_curated/on/on.0625.wav OK (270 ms)
# [ 783/1200] Uploading keywords_curated/on/on.0292.wav OK (288 ms)
# [ 784/1200] Uploading keywords_curated/on/on.0551.wav OK (260 ms)
# [ 785/1200] Uploading keywords_curated/on/on.0909.wav OK (416 ms)
# [ 786/1200] Uploading keywords_curated/on/on.0423.wav OK (386 ms)
# [ 787/1200] Uploading keywords_curated/on/on.1104.wav OK (229 ms)
# [ 788/1200] Uploading keywords_curated/on/on.0106.wav OK (294 ms)
# [ 789/1200] Uploading keywords_curated/on/on.1213.wav OK (265 ms)
# [ 790/1200] Uploading keywords_curated/on/on.1220.wav OK (249 ms)
# [ 791/1200] Uploading keywords_curated/on/on.1480.wav OK (285 ms)
# [ 792/1200] Uploading keywords_curated/on/on.1250.wav OK (350 ms)
# [ 793/1200] Uploading keywords_curated/on/on.1183.wav OK (269 ms)
# [ 794/1200] Uploading keywords_curated/on/on.0732.wav OK (400 ms)
# [ 795/1200] Uploading keywords_curated/on/on.1364.wav OK (415 ms)
# [ 796/1200] Uploading keywords_curated/on/on.0396.wav OK (236 ms)
# [ 797/1200] Uploading keywords_curated/on/on.0995.wav OK (334 ms)
# [ 798/1200] Uploading keywords_curated/on/on.1079.wav OK (301 ms)
# [ 799/1200] Uploading keywords_curated/on/on.0698.wav OK (283 ms)
# [ 800/1200] Uploading keywords_curated/on/on.1205.wav OK (317 ms)
# [ 801/1200] Uploading keywords_curated/on/on.0854.wav OK (228 ms)
# [ 802/1200] Uploading keywords_curated/on/on.0372.wav OK (269 ms)
# [ 803/1200] Uploading keywords_curated/on/on.1115.wav OK (253 ms)
# [ 804/1200] Uploading keywords_curated/on/on.1422.wav OK (294 ms)
# [ 805/1200] Uploading keywords_curated/on/on.0564.wav OK (287 ms)
# [ 806/1200] Uploading keywords_curated/on/on.0900.wav OK (272 ms)
# [ 807/1200] Uploading keywords_curated/on/on.0466.wav OK (295 ms)
# [ 808/1200] Uploading keywords_curated/on/on.0192.wav OK (266 ms)
# [ 809/1200] Uploading keywords_curated/on/on.0708.wav OK (281 ms)
# [ 810/1200] Uploading keywords_curated/on/on.0485.wav OK (280 ms)
# [ 811/1200] Uploading keywords_curated/on/on.0404.wav OK (269 ms)
# [ 812/1200] Uploading keywords_curated/on/on.0778.wav OK (353 ms)
# [ 813/1200] Uploading keywords_curated/on/on.0525.wav OK (341 ms)
# [ 814/1200] Uploading keywords_curated/on/on.1241.wav OK (323 ms)
# [ 815/1200] Uploading keywords_curated/on/on.0629.wav OK (275 ms)
# [ 816/1200] Uploading keywords_curated/on/on.1119.wav OK (410 ms)
# [ 817/1200] Uploading keywords_curated/on/on.1450.wav OK (307 ms)
# [ 818/1200] Uploading keywords_curated/on/on.1163.wav OK (445 ms)
# [ 819/1200] Uploading keywords_curated/on/on.0647.wav OK (250 ms)
# [ 820/1200] Uploading keywords_curated/on/on.0933.wav OK (347 ms)
# [ 821/1200] Uploading keywords_curated/on/on.1287.wav OK (268 ms)
# [ 822/1200] Uploading keywords_curated/on/on.1408.wav OK (447 ms)
# [ 823/1200] Uploading keywords_curated/on/on.0560.wav OK (285 ms)
# [ 824/1200] Uploading keywords_curated/on/on.0447.wav OK (272 ms)
# [ 825/1200] Uploading keywords_curated/on/on.0243.wav OK (220 ms)
# [ 826/1200] Uploading keywords_curated/on/on.0042.wav OK (299 ms)
# [ 827/1200] Uploading keywords_curated/on/on.0453.wav OK (253 ms)
# [ 828/1200] Uploading keywords_curated/on/on.0741.wav OK (236 ms)
# [ 829/1200] Uploading keywords_curated/on/on.0154.wav OK (302 ms)
# [ 830/1200] Uploading keywords_curated/on/on.0929.wav OK (423 ms)
# [ 831/1200] Uploading keywords_curated/on/on.0381.wav OK (239 ms)
# [ 832/1200] Uploading keywords_curated/on/on.0216.wav OK (435 ms)
# [ 833/1200] Uploading keywords_curated/on/on.1132.wav OK (280 ms)
# [ 834/1200] Uploading keywords_curated/on/on.0535.wav OK (295 ms)
# [ 835/1200] Uploading keywords_curated/on/on.0221.wav OK (278 ms)
# [ 836/1200] Uploading keywords_curated/on/on.0673.wav OK (259 ms)
# [ 837/1200] Uploading keywords_curated/on/on.1486.wav OK (243 ms)
# [ 838/1200] Uploading keywords_curated/on/on.1281.wav OK (238 ms)
# [ 839/1200] Uploading keywords_curated/on/on.0962.wav OK (296 ms)
# [ 840/1200] Uploading keywords_curated/on/on.1293.wav OK (243 ms)
# [ 841/1200] Uploading keywords_curated/on/on.0529.wav OK (274 ms)
# [ 842/1200] Uploading keywords_curated/on/on.1412.wav OK (241 ms)
# [ 843/1200] Uploading keywords_curated/on/on.1262.wav OK (255 ms)
# [ 844/1200] Uploading keywords_curated/on/on.0558.wav OK (292 ms)
# [ 845/1200] Uploading keywords_curated/on/on.0229.wav OK (241 ms)
# [ 846/1200] Uploading keywords_curated/on/on.0974.wav OK (257 ms)
# [ 847/1200] Uploading keywords_curated/on/on.0306.wav OK (329 ms)
# [ 848/1200] Uploading keywords_curated/on/on.1048.wav OK (283 ms)
# [ 849/1200] Uploading keywords_curated/on/on.0840.wav OK (434 ms)
# [ 850/1200] Uploading keywords_curated/on/on.0641.wav OK (281 ms)
# [ 851/1200] Uploading keywords_curated/on/on.1343.wav OK (264 ms)
# [ 852/1200] Uploading keywords_curated/on/on.0472.wav OK (277 ms)
# [ 853/1200] Uploading keywords_curated/on/on.1475.wav OK (318 ms)
# [ 854/1200] Uploading keywords_curated/on/on.0233.wav OK (369 ms)
# [ 855/1200] Uploading keywords_curated/on/on.1301.wav OK (300 ms)
# [ 856/1200] Uploading keywords_curated/on/on.1190.wav OK (234 ms)
# [ 857/1200] Uploading keywords_curated/on/on.0338.wav OK (308 ms)
# [ 858/1200] Uploading keywords_curated/on/on.0435.wav OK (258 ms)
# [ 859/1200] Uploading keywords_curated/on/on.1460.wav OK (243 ms)
# [ 860/1200] Uploading keywords_curated/on/on.0649.wav OK (286 ms)
# [ 861/1200] Uploading keywords_curated/on/on.1333.wav OK (290 ms)
# [ 862/1200] Uploading keywords_curated/on/on.0852.wav OK (257 ms)
# [ 863/1200] Uploading keywords_curated/on/on.0501.wav OK (375 ms)
# [ 864/1200] Uploading keywords_curated/on/on.0220.wav OK (234 ms)
# [ 865/1200] Uploading keywords_curated/on/on.0992.wav OK (254 ms)
# [ 866/1200] Uploading keywords_curated/on/on.1410.wav OK (224 ms)
# [ 867/1200] Uploading keywords_curated/on/on.0329.wav OK (285 ms)
# [ 868/1200] Uploading keywords_curated/on/on.0755.wav OK (229 ms)
# [ 869/1200] Uploading keywords_curated/on/on.0421.wav OK (260 ms)
# [ 870/1200] Uploading keywords_curated/on/on.1225.wav OK (326 ms)
# [ 871/1200] Uploading keywords_curated/on/on.0643.wav OK (398 ms)
# [ 872/1200] Uploading keywords_curated/on/on.0876.wav OK (249 ms)
# [ 873/1200] Uploading keywords_curated/on/on.1299.wav OK (415 ms)
# [ 874/1200] Uploading keywords_curated/on/on.0530.wav OK (229 ms)
# [ 875/1200] Uploading keywords_curated/on/on.1126.wav OK (277 ms)
# [ 876/1200] Uploading keywords_curated/on/on.0439.wav OK (420 ms)
# [ 877/1200] Uploading keywords_curated/on/on.0596.wav OK (266 ms)
# [ 878/1200] Uploading keywords_curated/on/on.0832.wav OK (282 ms)
# [ 879/1200] Uploading keywords_curated/on/on.1156.wav OK (391 ms)
# [ 880/1200] Uploading keywords_curated/on/on.0050.wav OK (457 ms)
# [ 881/1200] Uploading keywords_curated/on/on.1139.wav OK (302 ms)
# [ 882/1200] Uploading keywords_curated/on/on.1312.wav OK (230 ms)
# [ 883/1200] Uploading keywords_curated/on/on.0475.wav OK (418 ms)
# [ 884/1200] Uploading keywords_curated/on/on.0285.wav OK (288 ms)
# [ 885/1200] Uploading keywords_curated/on/on.0443.wav OK (267 ms)
# [ 886/1200] Uploading keywords_curated/on/on.0325.wav OK (300 ms)
# [ 887/1200] Uploading keywords_curated/on/on.0174.wav OK (283 ms)
# [ 888/1200] Uploading keywords_curated/on/on.0508.wav OK (391 ms)
# [ 889/1200] Uploading keywords_curated/on/on.1097.wav OK (265 ms)
# [ 890/1200] Uploading keywords_curated/on/on.0091.wav OK (266 ms)
# [ 891/1200] Uploading keywords_curated/on/on.0249.wav OK (250 ms)
# [ 892/1200] Uploading keywords_curated/on/on.1371.wav OK (298 ms)
# [ 893/1200] Uploading keywords_curated/on/on.1003.wav OK (509 ms)
# [ 894/1200] Uploading keywords_curated/on/on.1489.wav OK (277 ms)
# [ 895/1200] Uploading keywords_curated/on/on.0160.wav OK (295 ms)
# [ 896/1200] Uploading keywords_curated/on/on.0133.wav OK (438 ms)
# [ 897/1200] Uploading keywords_curated/on/on.0945.wav OK (262 ms)
# [ 898/1200] Uploading keywords_curated/on/on.1219.wav OK (247 ms)
# [ 899/1200] Uploading keywords_curated/on/on.0875.wav OK (211 ms)
# [ 900/1200] Uploading keywords_curated/on/on.0371.wav OK (356 ms)
# [ 901/1200] Uploading keywords_curated/on/on.0490.wav OK (322 ms)
# [ 902/1200] Uploading keywords_curated/on/on.0959.wav OK (247 ms)
# [ 903/1200] Uploading keywords_curated/on/on.1010.wav OK (265 ms)
# [ 904/1200] Uploading keywords_curated/on/on.0935.wav OK (272 ms)
# [ 905/1200] Uploading keywords_curated/on/on.0313.wav OK (243 ms)
# [ 906/1200] Uploading keywords_curated/on/on.1042.wav OK (289 ms)
# [ 907/1200] Uploading keywords_curated/on/on.0521.wav OK (322 ms)
# [ 908/1200] Uploading keywords_curated/on/on.0869.wav OK (239 ms)
# [ 909/1200] Uploading keywords_curated/on/on.0471.wav OK (259 ms)
# [ 910/1200] Uploading keywords_curated/on/on.0632.wav OK (270 ms)
# [ 911/1200] Uploading keywords_curated/on/on.1055.wav OK (410 ms)
# [ 912/1200] Uploading keywords_curated/on/on.1427.wav OK (411 ms)
# [ 913/1200] Uploading keywords_curated/on/on.0223.wav OK (278 ms)
# [ 914/1200] Uploading keywords_curated/on/on.0087.wav OK (257 ms)
# [ 915/1200] Uploading keywords_curated/on/on.1447.wav OK (337 ms)
# [ 916/1200] Uploading keywords_curated/on/on.1453.wav OK (217 ms)
# [ 917/1200] Uploading keywords_curated/on/on.0556.wav OK (251 ms)
# [ 918/1200] Uploading keywords_curated/on/on.0769.wav OK (275 ms)
# [ 919/1200] Uploading keywords_curated/on/on.0913.wav OK (269 ms)
# [ 920/1200] Uploading keywords_curated/on/on.0414.wav OK (270 ms)
# [ 921/1200] Uploading keywords_curated/on/on.0706.wav OK (252 ms)
# [ 922/1200] Uploading keywords_curated/on/on.1310.wav OK (395 ms)
# [ 923/1200] Uploading keywords_curated/on/on.0794.wav OK (286 ms)
# [ 924/1200] Uploading keywords_curated/on/on.0532.wav OK (458 ms)
# [ 925/1200] Uploading keywords_curated/on/on.0555.wav OK (283 ms)
# [ 926/1200] Uploading keywords_curated/on/on.0518.wav OK (252 ms)
# [ 927/1200] Uploading keywords_curated/on/on.0802.wav OK (233 ms)
# [ 928/1200] Uploading keywords_curated/on/on.1198.wav OK (270 ms)
# [ 929/1200] Uploading keywords_curated/on/on.0168.wav OK (436 ms)
# [ 930/1200] Uploading keywords_curated/on/on.1207.wav OK (245 ms)
# [ 931/1200] Uploading keywords_curated/on/on.0782.wav OK (315 ms)
# [ 932/1200] Uploading keywords_curated/on/on.0205.wav OK (240 ms)
# [ 933/1200] Uploading keywords_curated/on/on.0656.wav OK (275 ms)
# [ 934/1200] Uploading keywords_curated/on/on.0819.wav OK (224 ms)
# [ 935/1200] Uploading keywords_curated/on/on.0081.wav OK (262 ms)
# [ 936/1200] Uploading keywords_curated/on/on.0811.wav OK (250 ms)
# [ 937/1200] Uploading keywords_curated/on/on.1317.wav OK (341 ms)
# [ 938/1200] Uploading keywords_curated/on/on.0930.wav OK (276 ms)
# [ 939/1200] Uploading keywords_curated/on/on.1203.wav OK (293 ms)
# [ 940/1200] Uploading keywords_curated/on/on.0164.wav OK (262 ms)
# [ 941/1200] Uploading keywords_curated/on/on.0835.wav OK (261 ms)
# [ 942/1200] Uploading keywords_curated/on/on.1177.wav OK (225 ms)
# [ 943/1200] Uploading keywords_curated/on/on.1379.wav OK (262 ms)
# [ 944/1200] Uploading keywords_curated/on/on.1121.wav OK (322 ms)
# [ 945/1200] Uploading keywords_curated/on/on.1367.wav OK (440 ms)
# [ 946/1200] Uploading keywords_curated/on/on.0199.wav OK (290 ms)
# [ 947/1200] Uploading keywords_curated/on/on.1166.wav OK (277 ms)
# [ 948/1200] Uploading keywords_curated/on/on.0000.wav OK (309 ms)
# [ 949/1200] Uploading keywords_curated/on/on.0636.wav OK (328 ms)
# [ 950/1200] Uploading keywords_curated/on/on.0687.wav OK (288 ms)
# [ 951/1200] Uploading keywords_curated/on/on.0897.wav OK (288 ms)
# [ 952/1200] Uploading keywords_curated/on/on.1113.wav OK (273 ms)
# [ 953/1200] Uploading keywords_curated/on/on.0753.wav OK (257 ms)
# [ 954/1200] Uploading keywords_curated/on/on.0360.wav OK (258 ms)
# [ 955/1200] Uploading keywords_curated/on/on.0939.wav OK (412 ms)
# [ 956/1200] Uploading keywords_curated/on/on.1380.wav OK (288 ms)
# [ 957/1200] Uploading keywords_curated/on/on.1050.wav OK (272 ms)
# [ 958/1200] Uploading keywords_curated/on/on.0754.wav OK (274 ms)
# [ 959/1200] Uploading keywords_curated/on/on.1067.wav OK (258 ms)
# [ 960/1200] Uploading keywords_curated/on/on.0057.wav OK (260 ms)
# [ 961/1200] Uploading keywords_curated/on/on.1005.wav OK (276 ms)
# [ 962/1200] Uploading keywords_curated/on/on.0301.wav OK (269 ms)
# [ 963/1200] Uploading keywords_curated/on/on.0411.wav OK (270 ms)
# [ 964/1200] Uploading keywords_curated/on/on.1028.wav OK (255 ms)
# [ 965/1200] Uploading keywords_curated/on/on.0104.wav OK (252 ms)
# [ 966/1200] Uploading keywords_curated/on/on.1051.wav OK (289 ms)
# [ 967/1200] Uploading keywords_curated/on/on.0633.wav OK (427 ms)
# [ 968/1200] Uploading keywords_curated/on/on.0450.wav OK (271 ms)
# [ 969/1200] Uploading keywords_curated/on/on.0756.wav OK (300 ms)
# [ 970/1200] Uploading keywords_curated/on/on.0860.wav OK (288 ms)
# [ 971/1200] Uploading keywords_curated/on/on.0150.wav OK (271 ms)
# [ 972/1200] Uploading keywords_curated/on/on.0574.wav OK (254 ms)
# [ 973/1200] Uploading keywords_curated/on/on.0071.wav OK (456 ms)
# [ 974/1200] Uploading keywords_curated/on/on.0787.wav OK (289 ms)
# [ 975/1200] Uploading keywords_curated/on/on.0912.wav OK (305 ms)
# [ 976/1200] Uploading keywords_curated/on/on.1494.wav OK (442 ms)
# [ 977/1200] Uploading keywords_curated/on/on.0235.wav OK (274 ms)
# [ 978/1200] Uploading keywords_curated/on/on.1375.wav OK (240 ms)
# [ 979/1200] Uploading keywords_curated/on/on.1172.wav OK (329 ms)
# [ 980/1200] Uploading keywords_curated/on/on.1297.wav OK (391 ms)
# [ 981/1200] Uploading keywords_curated/on/on.0111.wav OK (359 ms)
# [ 982/1200] Uploading keywords_curated/on/on.1266.wav OK (312 ms)
# [ 983/1200] Uploading keywords_curated/on/on.0847.wav OK (300 ms)
# [ 984/1200] Uploading keywords_curated/on/on.1257.wav OK (283 ms)
# [ 985/1200] Uploading keywords_curated/on/on.0207.wav OK (267 ms)
# [ 986/1200] Uploading keywords_curated/on/on.0516.wav OK (302 ms)
# [ 987/1200] Uploading keywords_curated/on/on.0256.wav OK (282 ms)
# [ 988/1200] Uploading keywords_curated/on/on.0006.wav OK (318 ms)
# [ 989/1200] Uploading keywords_curated/on/on.0047.wav OK (321 ms)
# [ 990/1200] Uploading keywords_curated/on/on.0844.wav OK (307 ms)
# [ 991/1200] Uploading keywords_curated/on/on.0426.wav OK (292 ms)
# [ 992/1200] Uploading keywords_curated/on/on.0714.wav OK (299 ms)
# [ 993/1200] Uploading keywords_curated/on/on.0145.wav OK (440 ms)
# [ 994/1200] Uploading keywords_curated/on/on.0730.wav OK (250 ms)
# [ 995/1200] Uploading keywords_curated/on/on.1497.wav OK (271 ms)
# [ 996/1200] Uploading keywords_curated/on/on.1491.wav OK (325 ms)
# [ 997/1200] Uploading keywords_curated/on/on.1049.wav OK (232 ms)
# [ 998/1200] Uploading keywords_curated/on/on.0058.wav OK (300 ms)
# [ 999/1200] Uploading keywords_curated/on/on.0666.wav OK (254 ms)
# [1000/1200] Uploading keywords_curated/on/on.0253.wav OK (269 ms)
# [1001/1200] Uploading keywords_curated/on/on.0310.wav OK (433 ms)
# [1002/1200] Uploading keywords_curated/on/on.0105.wav OK (456 ms)
# [1003/1200] Uploading keywords_curated/on/on.0936.wav OK (269 ms)
# [1004/1200] Uploading keywords_curated/on/on.1123.wav OK (288 ms)
# [1005/1200] Uploading keywords_curated/on/on.0638.wav OK (233 ms)
# [1006/1200] Uploading keywords_curated/on/on.0996.wav OK (281 ms)
# [1007/1200] Uploading keywords_curated/on/on.0702.wav OK (250 ms)
# [1008/1200] Uploading keywords_curated/on/on.0999.wav OK (371 ms)
# [1009/1200] Uploading keywords_curated/on/on.1284.wav OK (275 ms)
# [1010/1200] Uploading keywords_curated/on/on.1432.wav OK (273 ms)
# [1011/1200] Uploading keywords_curated/on/on.0733.wav OK (250 ms)
# [1012/1200] Uploading keywords_curated/on/on.0134.wav OK (230 ms)
# [1013/1200] Uploading keywords_curated/on/on.1075.wav OK (249 ms)
# [1014/1200] Uploading keywords_curated/on/on.0357.wav OK (300 ms)
# [1015/1200] Uploading keywords_curated/on/on.0171.wav OK (231 ms)
# [1016/1200] Uploading keywords_curated/on/on.0390.wav OK (394 ms)
# [1017/1200] Uploading keywords_curated/on/on.0027.wav OK (229 ms)
# [1018/1200] Uploading keywords_curated/on/on.0271.wav OK (280 ms)
# [1019/1200] Uploading keywords_curated/on/on.0347.wav OK (406 ms)
# [1020/1200] Uploading keywords_curated/on/on.1248.wav OK (462 ms)
# [1021/1200] Uploading keywords_curated/on/on.1415.wav OK (285 ms)
# [1022/1200] Uploading keywords_curated/on/on.1254.wav OK (303 ms)
# [1023/1200] Uploading keywords_curated/on/on.0049.wav OK (212 ms)
# [1024/1200] Uploading keywords_curated/on/on.0403.wav OK (323 ms)
# [1025/1200] Uploading keywords_curated/on/on.0799.wav OK (264 ms)
# [1026/1200] Uploading keywords_curated/on/on.0236.wav OK (243 ms)
# [1027/1200] Uploading keywords_curated/on/on.0695.wav OK (279 ms)
# [1028/1200] Uploading keywords_curated/on/on.0707.wav OK (293 ms)
# [1029/1200] Uploading keywords_curated/on/on.0985.wav OK (261 ms)
# [1030/1200] Uploading keywords_curated/on/on.1201.wav OK (276 ms)
# [1031/1200] Uploading keywords_curated/on/on.1066.wav OK (415 ms)
# [1032/1200] Uploading keywords_curated/on/on.0653.wav OK (295 ms)
# [1033/1200] Uploading keywords_curated/on/on.1355.wav OK (277 ms)
# [1034/1200] Uploading keywords_curated/on/on.0070.wav OK (395 ms)
# [1035/1200] Uploading keywords_curated/on/on.0352.wav OK (263 ms)
# [1036/1200] Uploading keywords_curated/on/on.0315.wav OK (286 ms)
# [1037/1200] Uploading keywords_curated/on/on.0887.wav OK (327 ms)
# [1038/1200] Uploading keywords_curated/on/on.0552.wav OK (301 ms)
# [1039/1200] Uploading keywords_curated/on/on.0084.wav OK (264 ms)
# [1040/1200] Uploading keywords_curated/on/on.0409.wav OK (298 ms)
# [1041/1200] Uploading keywords_curated/on/on.0678.wav OK (284 ms)
# [1042/1200] Uploading keywords_curated/on/on.0941.wav OK (237 ms)
# [1043/1200] Uploading keywords_curated/on/on.0068.wav OK (270 ms)
# [1044/1200] Uploading keywords_curated/on/on.0165.wav OK (272 ms)
# [1045/1200] Uploading keywords_curated/on/on.1232.wav OK (290 ms)
# [1046/1200] Uploading keywords_curated/on/on.0613.wav OK (389 ms)
# [1047/1200] Uploading keywords_curated/on/on.1314.wav OK (243 ms)
# [1048/1200] Uploading keywords_curated/on/on.0721.wav OK (273 ms)
# [1049/1200] Uploading keywords_curated/on/on.0921.wav OK (323 ms)
# [1050/1200] Uploading keywords_curated/on/on.0499.wav OK (390 ms)
# [1051/1200] Uploading keywords_curated/on/on.0432.wav OK (259 ms)
# [1052/1200] Uploading keywords_curated/on/on.0151.wav OK (361 ms)
# [1053/1200] Uploading keywords_curated/on/on.0947.wav OK (281 ms)
# [1054/1200] Uploading keywords_curated/on/on.0950.wav OK (312 ms)
# [1055/1200] Uploading keywords_curated/on/on.0748.wav OK (297 ms)
# [1056/1200] Uploading keywords_curated/on/on.0407.wav OK (337 ms)
# [1057/1200] Uploading keywords_curated/on/on.1356.wav OK (284 ms)
# [1058/1200] Uploading keywords_curated/on/on.0542.wav OK (321 ms)
# [1059/1200] Uploading keywords_curated/on/on.1457.wav OK (253 ms)
# [1060/1200] Uploading keywords_curated/on/on.0267.wav OK (302 ms)
# [1061/1200] Uploading keywords_curated/on/on.0354.wav OK (269 ms)
# [1062/1200] Uploading keywords_curated/on/on.1296.wav OK (332 ms)
# [1063/1200] Uploading keywords_curated/on/on.0398.wav OK (314 ms)
# [1064/1200] Uploading keywords_curated/on/on.0715.wav OK (354 ms)
# [1065/1200] Uploading keywords_curated/on/on.0486.wav OK (284 ms)
# [1066/1200] Uploading keywords_curated/on/on.0263.wav OK (299 ms)
# [1067/1200] Uploading keywords_curated/on/on.0833.wav OK (267 ms)
# [1068/1200] Uploading keywords_curated/on/on.0704.wav OK (253 ms)
# [1069/1200] Uploading keywords_curated/on/on.0302.wav OK (333 ms)
# [1070/1200] Uploading keywords_curated/on/on.0138.wav OK (316 ms)
# [1071/1200] Uploading keywords_curated/on/on.0864.wav OK (299 ms)
# [1072/1200] Uploading keywords_curated/on/on.1348.wav OK (348 ms)
# [1073/1200] Uploading keywords_curated/on/on.1419.wav OK (310 ms)
# [1074/1200] Uploading keywords_curated/on/on.0416.wav OK (420 ms)
# [1075/1200] Uploading keywords_curated/on/on.0830.wav OK (264 ms)
# [1076/1200] Uploading keywords_curated/on/on.0671.wav OK (325 ms)
# [1077/1200] Uploading keywords_curated/on/on.0914.wav OK (280 ms)
# [1078/1200] Uploading keywords_curated/on/on.0452.wav OK (296 ms)
# [1079/1200] Uploading keywords_curated/on/on.0102.wav OK (435 ms)
# [1080/1200] Uploading keywords_curated/on/on.0108.wav OK (230 ms)
# [1081/1200] Uploading keywords_curated/on/on.0509.wav OK (308 ms)
# [1082/1200] Uploading keywords_curated/on/on.1217.wav OK (293 ms)
# [1083/1200] Uploading keywords_curated/on/on.1350.wav OK (245 ms)
# [1084/1200] Uploading keywords_curated/on/on.0534.wav OK (344 ms)
# [1085/1200] Uploading keywords_curated/on/on.0326.wav OK (460 ms)
# [1086/1200] Uploading keywords_curated/on/on.0623.wav OK (474 ms)
# [1087/1200] Uploading keywords_curated/on/on.0040.wav OK (233 ms)
# [1088/1200] Uploading keywords_curated/on/on.1498.wav OK (283 ms)
# [1089/1200] Uploading keywords_curated/on/on.0259.wav OK (400 ms)
# [1090/1200] Uploading keywords_curated/on/on.0699.wav OK (341 ms)
# [1091/1200] Uploading keywords_curated/on/on.0484.wav OK (290 ms)
# [1092/1200] Uploading keywords_curated/on/on.1363.wav OK (275 ms)
# [1093/1200] Uploading keywords_curated/on/on.0738.wav OK (293 ms)
# [1094/1200] Uploading keywords_curated/on/on.0807.wav OK (413 ms)
# [1095/1200] Uploading keywords_curated/on/on.1373.wav OK (295 ms)
# [1096/1200] Uploading keywords_curated/on/on.0976.wav OK (265 ms)
# [1097/1200] Uploading keywords_curated/on/on.1059.wav OK (279 ms)
# [1098/1200] Uploading keywords_curated/on/on.0923.wav OK (249 ms)
# [1099/1200] Uploading keywords_curated/on/on.1143.wav OK (345 ms)
# [1100/1200] Uploading keywords_curated/on/on.1346.wav OK (331 ms)
# [1101/1200] Uploading keywords_curated/on/on.0257.wav OK (290 ms)
# [1102/1200] Uploading keywords_curated/on/on.0515.wav OK (290 ms)
# [1103/1200] Uploading keywords_curated/on/on.0279.wav OK (273 ms)
# [1104/1200] Uploading keywords_curated/on/on.0650.wav OK (259 ms)
# [1105/1200] Uploading keywords_curated/on/on.1499.wav OK (264 ms)
# [1106/1200] Uploading keywords_curated/on/on.0801.wav OK (348 ms)
# [1107/1200] Uploading keywords_curated/on/on.0955.wav OK (311 ms)
# [1108/1200] Uploading keywords_curated/on/on.0724.wav OK (291 ms)
# [1109/1200] Uploading keywords_curated/on/on.1208.wav OK (277 ms)
# [1110/1200] Uploading keywords_curated/on/on.0195.wav OK (315 ms)
# [1111/1200] Uploading keywords_curated/on/on.0388.wav OK (259 ms)
# [1112/1200] Uploading keywords_curated/on/on.1134.wav OK (227 ms)
# [1113/1200] Uploading keywords_curated/on/on.0977.wav OK (281 ms)
# [1114/1200] Uploading keywords_curated/on/on.1084.wav OK (248 ms)
# [1115/1200] Uploading keywords_curated/on/on.0507.wav OK (248 ms)
# [1116/1200] Uploading keywords_curated/on/on.1085.wav OK (273 ms)
# [1117/1200] Uploading keywords_curated/on/on.0052.wav OK (255 ms)
# [1118/1200] Uploading keywords_curated/on/on.0583.wav OK (456 ms)
# [1119/1200] Uploading keywords_curated/on/on.1235.wav OK (404 ms)
# [1120/1200] Uploading keywords_curated/on/on.0737.wav OK (432 ms)
# [1121/1200] Uploading keywords_curated/on/on.1325.wav OK (248 ms)
# [1122/1200] Uploading keywords_curated/on/on.0718.wav OK (354 ms)
# [1123/1200] Uploading keywords_curated/on/on.0820.wav OK (251 ms)
# [1124/1200] Uploading keywords_curated/on/on.1448.wav OK (450 ms)
# [1125/1200] Uploading keywords_curated/on/on.0142.wav OK (318 ms)
# [1126/1200] Uploading keywords_curated/on/on.0182.wav OK (303 ms)
# [1127/1200] Uploading keywords_curated/on/on.1463.wav OK (418 ms)
# [1128/1200] Uploading keywords_curated/on/on.1116.wav OK (286 ms)
# [1129/1200] Uploading keywords_curated/on/on.0759.wav OK (318 ms)
# [1130/1200] Uploading keywords_curated/on/on.1199.wav OK (248 ms)
# [1131/1200] Uploading keywords_curated/on/on.0245.wav OK (307 ms)
# [1132/1200] Uploading keywords_curated/on/on.1047.wav OK (454 ms)
# [1133/1200] Uploading keywords_curated/on/on.1035.wav OK (291 ms)
# [1134/1200] Uploading keywords_curated/on/on.1078.wav OK (348 ms)
# [1135/1200] Uploading keywords_curated/on/on.0654.wav OK (308 ms)
# [1136/1200] Uploading keywords_curated/on/on.0377.wav OK (276 ms)
# [1137/1200] Uploading keywords_curated/on/on.0175.wav OK (433 ms)
# [1138/1200] Uploading keywords_curated/on/on.0041.wav OK (262 ms)
# [1139/1200] Uploading keywords_curated/on/on.0576.wav OK (246 ms)
# [1140/1200] Uploading keywords_curated/on/on.0276.wav OK (337 ms)
# [1141/1200] Uploading keywords_curated/on/on.0214.wav OK (306 ms)
# [1142/1200] Uploading keywords_curated/on/on.0998.wav OK (284 ms)
# [1143/1200] Uploading keywords_curated/on/on.0792.wav OK (307 ms)
# [1144/1200] Uploading keywords_curated/on/on.1008.wav OK (278 ms)
# [1145/1200] Uploading keywords_curated/on/on.0545.wav OK (240 ms)
# [1146/1200] Uploading keywords_curated/on/on.1124.wav OK (273 ms)
# [1147/1200] Uploading keywords_curated/on/on.1417.wav OK (465 ms)
# [1148/1200] Uploading keywords_curated/on/on.1148.wav OK (224 ms)
# [1149/1200] Uploading keywords_curated/on/on.1409.wav OK (290 ms)
# [1150/1200] Uploading keywords_curated/on/on.1238.wav OK (420 ms)
# [1151/1200] Uploading keywords_curated/on/on.1069.wav OK (454 ms)
# [1152/1200] Uploading keywords_curated/on/on.0662.wav OK (282 ms)
# [1153/1200] Uploading keywords_curated/on/on.0554.wav OK (242 ms)
# [1154/1200] Uploading keywords_curated/on/on.0277.wav OK (325 ms)
# [1155/1200] Uploading keywords_curated/on/on.1265.wav OK (388 ms)
# [1156/1200] Uploading keywords_curated/on/on.0597.wav OK (296 ms)
# [1157/1200] Uploading keywords_curated/on/on.0502.wav OK (470 ms)
# [1158/1200] Uploading keywords_curated/on/on.1052.wav OK (271 ms)
# [1159/1200] Uploading keywords_curated/on/on.0624.wav OK (287 ms)
# [1160/1200] Uploading keywords_curated/on/on.0880.wav OK (233 ms)
# [1161/1200] Uploading keywords_curated/on/on.0035.wav OK (257 ms)
# [1162/1200] Uploading keywords_curated/on/on.0297.wav OK (315 ms)
# [1163/1200] Uploading keywords_curated/on/on.0375.wav OK (450 ms)
# [1164/1200] Uploading keywords_curated/on/on.1274.wav OK (287 ms)
# [1165/1200] Uploading keywords_curated/on/on.0920.wav OK (495 ms)
# [1166/1200] Uploading keywords_curated/on/on.0761.wav OK (436 ms)
# [1167/1200] Uploading keywords_curated/on/on.0948.wav OK (274 ms)
# [1168/1200] Uploading keywords_curated/on/on.0710.wav OK (306 ms)
# [1169/1200] Uploading keywords_curated/on/on.0089.wav OK (248 ms)
# [1170/1200] Uploading keywords_curated/on/on.0793.wav OK (285 ms)
# [1171/1200] Uploading keywords_curated/on/on.0562.wav OK (269 ms)
# [1172/1200] Uploading keywords_curated/on/on.0365.wav OK (246 ms)
# [1173/1200] Uploading keywords_curated/on/on.1086.wav OK (275 ms)
# [1174/1200] Uploading keywords_curated/on/on.0776.wav OK (442 ms)
# [1175/1200] Uploading keywords_curated/on/on.0261.wav OK (293 ms)
# [1176/1200] Uploading keywords_curated/on/on.0327.wav OK (263 ms)
# [1177/1200] Uploading keywords_curated/on/on.1106.wav OK (317 ms)
# [1178/1200] Uploading keywords_curated/on/on.0391.wav OK (275 ms)
# [1179/1200] Uploading keywords_curated/on/on.1465.wav OK (310 ms)
# [1180/1200] Uploading keywords_curated/on/on.0777.wav OK (293 ms)
# [1181/1200] Uploading keywords_curated/on/on.0829.wav OK (273 ms)
# [1182/1200] Uploading keywords_curated/on/on.0831.wav OK (323 ms)
# [1183/1200] Uploading keywords_curated/on/on.1034.wav OK (257 ms)
# [1184/1200] Uploading keywords_curated/on/on.0467.wav OK (289 ms)
# [1185/1200] Uploading keywords_curated/on/on.0599.wav OK (274 ms)
# [1186/1200] Uploading keywords_curated/on/on.0828.wav OK (233 ms)
# [1187/1200] Uploading keywords_curated/on/on.0487.wav OK (257 ms)
# [1188/1200] Uploading keywords_curated/on/on.0026.wav OK (232 ms)
# [1189/1200] Uploading keywords_curated/on/on.1472.wav OK (221 ms)
# [1190/1200] Uploading keywords_curated/on/on.0731.wav OK (213 ms)
# [1191/1200] Uploading keywords_curated/on/on.0152.wav OK (267 ms)
# [1192/1200] Uploading keywords_curated/on/on.1153.wav OK (279 ms)
# [1193/1200] Uploading keywords_curated/on/on.0213.wav OK (300 ms)
# [1194/1200] Uploading keywords_curated/on/on.0894.wav OK (246 ms)
# [1195/1200] Uploading keywords_curated/on/on.1272.wav OK (248 ms)
# [1196/1200] Uploading keywords_curated/on/on.0126.wav OK (419 ms)
# [1197/1200] Uploading keywords_curated/on/on.0911.wav OK (266 ms)
# [1198/1200] Uploading keywords_curated/on/on.1122.wav OK (243 ms)
# [1199/1200] Uploading keywords_curated/on/on.0209.wav OK (396 ms)
# [1200/1200] Uploading keywords_curated/on/on.1233.wav OK (363 ms)
# labelsFile /content/keywords_curated/_unknown/bounding_boxes.labels
# [  1/300] Uploading keywords_curated/_unknown/_unknown.0391.wav OK (1386 ms)
# [  2/300] Uploading keywords_curated/_unknown/_unknown.0590.wav OK (1231 ms)
# [  3/300] Uploading keywords_curated/_unknown/_unknown.0932.wav OK (1183 ms)
# [  4/300] Uploading keywords_curated/_unknown/_unknown.0677.wav OK (1025 ms)
# [  5/300] Uploading keywords_curated/_unknown/_unknown.0012.wav OK (1259 ms)
# [  6/300] Uploading keywords_curated/_unknown/_unknown.0902.wav OK (1206 ms)
# [  7/300] Uploading keywords_curated/_unknown/_unknown.1107.wav OK (1224 ms)
# [  8/300] Uploading keywords_curated/_unknown/_unknown.0622.wav OK (1209 ms)
# [  9/300] Uploading keywords_curated/_unknown/_unknown.0052.wav OK (1118 ms)
# [ 10/300] Uploading keywords_curated/_unknown/_unknown.1230.wav OK (1105 ms)
# [ 11/300] Uploading keywords_curated/_unknown/_unknown.1090.wav OK (1197 ms)
# [ 12/300] Uploading keywords_curated/_unknown/_unknown.0468.wav OK (1328 ms)
# [ 13/300] Uploading keywords_curated/_unknown/_unknown.1429.wav OK (1050 ms)
# [ 14/300] Uploading keywords_curated/_unknown/_unknown.0954.wav OK (1167 ms)
# [ 15/300] Uploading keywords_curated/_unknown/_unknown.0914.wav OK (1441 ms)
# [ 16/300] Uploading keywords_curated/_unknown/_unknown.0325.wav OK (1201 ms)
# [ 17/300] Uploading keywords_curated/_unknown/_unknown.0485.wav OK (1300 ms)
# [ 18/300] Uploading keywords_curated/_unknown/_unknown.1263.wav OK (1385 ms)
# [ 19/300] Uploading keywords_curated/_unknown/_unknown.0348.wav OK (1158 ms)
# [ 20/300] Uploading keywords_curated/_unknown/_unknown.1123.wav OK (1173 ms)
# [ 21/300] Uploading keywords_curated/_unknown/_unknown.1071.wav OK (326 ms)
# [ 22/300] Uploading keywords_curated/_unknown/_unknown.1084.wav OK (327 ms)
# [ 23/300] Uploading keywords_curated/_unknown/_unknown.1349.wav OK (311 ms)
# [ 24/300] Uploading keywords_curated/_unknown/_unknown.1148.wav OK (349 ms)
# [ 25/300] Uploading keywords_curated/_unknown/_unknown.1121.wav OK (384 ms)
# [ 26/300] Uploading keywords_curated/_unknown/_unknown.0864.wav OK (380 ms)
# [ 27/300] Uploading keywords_curated/_unknown/_unknown.0112.wav OK (457 ms)
# [ 28/300] Uploading keywords_curated/_unknown/_unknown.1451.wav OK (395 ms)
# [ 29/300] Uploading keywords_curated/_unknown/_unknown.0577.wav OK (475 ms)
# [ 30/300] Uploading keywords_curated/_unknown/_unknown.1487.wav OK (429 ms)
# [ 31/300] Uploading keywords_curated/_unknown/_unknown.1420.wav OK (447 ms)
# [ 32/300] Uploading keywords_curated/_unknown/_unknown.0686.wav OK (400 ms)
# [ 33/300] Uploading keywords_curated/_unknown/_unknown.0140.wav OK (518 ms)
# [ 34/300] Uploading keywords_curated/_unknown/_unknown.0872.wav OK (434 ms)
# [ 35/300] Uploading keywords_curated/_unknown/_unknown.1401.wav OK (267 ms)
# [ 36/300] Uploading keywords_curated/_unknown/_unknown.0880.wav OK (234 ms)
# [ 37/300] Uploading keywords_curated/_unknown/_unknown.0034.wav OK (385 ms)
# [ 38/300] Uploading keywords_curated/_unknown/_unknown.1410.wav OK (252 ms)
# [ 39/300] Uploading keywords_curated/_unknown/_unknown.0800.wav OK (484 ms)
# [ 40/300] Uploading keywords_curated/_unknown/_unknown.0039.wav OK (252 ms)
# [ 41/300] Uploading keywords_curated/_unknown/_unknown.0121.wav OK (421 ms)
# [ 42/300] Uploading keywords_curated/_unknown/_unknown.1134.wav OK (451 ms)
# [ 43/300] Uploading keywords_curated/_unknown/_unknown.0056.wav OK (522 ms)
# [ 44/300] Uploading keywords_curated/_unknown/_unknown.0900.wav OK (507 ms)
# [ 45/300] Uploading keywords_curated/_unknown/_unknown.1304.wav OK (424 ms)
# [ 46/300] Uploading keywords_curated/_unknown/_unknown.0072.wav OK (457 ms)
# [ 47/300] Uploading keywords_curated/_unknown/_unknown.0572.wav OK (256 ms)
# [ 48/300] Uploading keywords_curated/_unknown/_unknown.1034.wav OK (274 ms)
# [ 49/300] Uploading keywords_curated/_unknown/_unknown.0631.wav OK (260 ms)
# [ 50/300] Uploading keywords_curated/_unknown/_unknown.1122.wav OK (304 ms)
# [ 51/300] Uploading keywords_curated/_unknown/_unknown.0349.wav OK (291 ms)
# [ 52/300] Uploading keywords_curated/_unknown/_unknown.0268.wav OK (322 ms)
# [ 53/300] Uploading keywords_curated/_unknown/_unknown.0474.wav OK (303 ms)
# [ 54/300] Uploading keywords_curated/_unknown/_unknown.0190.wav OK (271 ms)
# [ 55/300] Uploading keywords_curated/_unknown/_unknown.0447.wav OK (243 ms)
# [ 56/300] Uploading keywords_curated/_unknown/_unknown.0586.wav OK (276 ms)
# [ 57/300] Uploading keywords_curated/_unknown/_unknown.0080.wav OK (311 ms)
# [ 58/300] Uploading keywords_curated/_unknown/_unknown.0923.wav OK (259 ms)
# [ 59/300] Uploading keywords_curated/_unknown/_unknown.1183.wav OK (258 ms)
# [ 60/300] Uploading keywords_curated/_unknown/_unknown.0312.wav OK (401 ms)
# [ 61/300] Uploading keywords_curated/_unknown/_unknown.0406.wav OK (271 ms)
# [ 62/300] Uploading keywords_curated/_unknown/_unknown.0562.wav OK (272 ms)
# [ 63/300] Uploading keywords_curated/_unknown/_unknown.0841.wav OK (402 ms)
# [ 64/300] Uploading keywords_curated/_unknown/_unknown.0436.wav OK (454 ms)
# [ 65/300] Uploading keywords_curated/_unknown/_unknown.0453.wav OK (436 ms)
# [ 66/300] Uploading keywords_curated/_unknown/_unknown.0661.wav OK (441 ms)
# [ 67/300] Uploading keywords_curated/_unknown/_unknown.0353.wav OK (426 ms)
# [ 68/300] Uploading keywords_curated/_unknown/_unknown.0692.wav OK (272 ms)
# [ 69/300] Uploading keywords_curated/_unknown/_unknown.0041.wav OK (382 ms)
# [ 70/300] Uploading keywords_curated/_unknown/_unknown.0207.wav OK (289 ms)
# [ 71/300] Uploading keywords_curated/_unknown/_unknown.0199.wav OK (336 ms)
# [ 72/300] Uploading keywords_curated/_unknown/_unknown.0265.wav OK (484 ms)
# [ 73/300] Uploading keywords_curated/_unknown/_unknown.0245.wav OK (278 ms)
# [ 74/300] Uploading keywords_curated/_unknown/_unknown.0729.wav OK (419 ms)
# [ 75/300] Uploading keywords_curated/_unknown/_unknown.1102.wav OK (396 ms)
# [ 76/300] Uploading keywords_curated/_unknown/_unknown.0423.wav OK (311 ms)
# [ 77/300] Uploading keywords_curated/_unknown/_unknown.1269.wav OK (262 ms)
# [ 78/300] Uploading keywords_curated/_unknown/_unknown.0172.wav OK (316 ms)
# [ 79/300] Uploading keywords_curated/_unknown/_unknown.1125.wav OK (289 ms)
# [ 80/300] Uploading keywords_curated/_unknown/_unknown.0202.wav OK (273 ms)
# [ 81/300] Uploading keywords_curated/_unknown/_unknown.1041.wav OK (450 ms)
# [ 82/300] Uploading keywords_curated/_unknown/_unknown.0223.wav OK (420 ms)
# [ 83/300] Uploading keywords_curated/_unknown/_unknown.0838.wav OK (257 ms)
# [ 84/300] Uploading keywords_curated/_unknown/_unknown.1354.wav OK (334 ms)
# [ 85/300] Uploading keywords_curated/_unknown/_unknown.0354.wav OK (298 ms)
# [ 86/300] Uploading keywords_curated/_unknown/_unknown.0448.wav OK (318 ms)
# [ 87/300] Uploading keywords_curated/_unknown/_unknown.1157.wav OK (317 ms)
# [ 88/300] Uploading keywords_curated/_unknown/_unknown.0259.wav OK (303 ms)
# [ 89/300] Uploading keywords_curated/_unknown/_unknown.1445.wav OK (263 ms)
# [ 90/300] Uploading keywords_curated/_unknown/_unknown.0619.wav OK (247 ms)
# [ 91/300] Uploading keywords_curated/_unknown/_unknown.1176.wav OK (420 ms)
# [ 92/300] Uploading keywords_curated/_unknown/_unknown.0734.wav OK (378 ms)
# [ 93/300] Uploading keywords_curated/_unknown/_unknown.1279.wav OK (271 ms)
# [ 94/300] Uploading keywords_curated/_unknown/_unknown.0537.wav OK (299 ms)
# [ 95/300] Uploading keywords_curated/_unknown/_unknown.0603.wav OK (288 ms)
# [ 96/300] Uploading keywords_curated/_unknown/_unknown.0215.wav OK (274 ms)
# [ 97/300] Uploading keywords_curated/_unknown/_unknown.0017.wav OK (322 ms)
# [ 98/300] Uploading keywords_curated/_unknown/_unknown.0813.wav OK (260 ms)
# [ 99/300] Uploading keywords_curated/_unknown/_unknown.0591.wav OK (468 ms)
# [100/300] Uploading keywords_curated/_unknown/_unknown.0695.wav OK (277 ms)
# [101/300] Uploading keywords_curated/_unknown/_unknown.0035.wav OK (506 ms)
# [102/300] Uploading keywords_curated/_unknown/_unknown.1024.wav OK (277 ms)
# [103/300] Uploading keywords_curated/_unknown/_unknown.0368.wav OK (261 ms)
# [104/300] Uploading keywords_curated/_unknown/_unknown.1061.wav OK (295 ms)
# [105/300] Uploading keywords_curated/_unknown/_unknown.0808.wav OK (541 ms)
# [106/300] Uploading keywords_curated/_unknown/_unknown.1341.wav OK (510 ms)
# [107/300] Uploading keywords_curated/_unknown/_unknown.0055.wav OK (234 ms)
# [108/300] Uploading keywords_curated/_unknown/_unknown.1367.wav OK (502 ms)
# [109/300] Uploading keywords_curated/_unknown/_unknown.1332.wav OK (258 ms)
# [110/300] Uploading keywords_curated/_unknown/_unknown.0376.wav OK (451 ms)
# [111/300] Uploading keywords_curated/_unknown/_unknown.1227.wav OK (306 ms)
# [112/300] Uploading keywords_curated/_unknown/_unknown.0908.wav OK (420 ms)
# [113/300] Uploading keywords_curated/_unknown/_unknown.1370.wav OK (288 ms)
# [114/300] Uploading keywords_curated/_unknown/_unknown.1074.wav OK (345 ms)
# [115/300] Uploading keywords_curated/_unknown/_unknown.0105.wav OK (308 ms)
# [116/300] Uploading keywords_curated/_unknown/_unknown.0716.wav OK (327 ms)
# [117/300] Uploading keywords_curated/_unknown/_unknown.1426.wav OK (291 ms)
# [118/300] Uploading keywords_curated/_unknown/_unknown.1156.wav OK (275 ms)
# [119/300] Uploading keywords_curated/_unknown/_unknown.0556.wav OK (302 ms)
# [120/300] Uploading keywords_curated/_unknown/_unknown.0270.wav OK (325 ms)
# [121/300] Uploading keywords_curated/_unknown/_unknown.1299.wav OK (341 ms)
# [122/300] Uploading keywords_curated/_unknown/_unknown.0473.wav OK (270 ms)
# [123/300] Uploading keywords_curated/_unknown/_unknown.1453.wav OK (241 ms)
# [124/300] Uploading keywords_curated/_unknown/_unknown.0373.wav OK (345 ms)
# [125/300] Uploading keywords_curated/_unknown/_unknown.0384.wav OK (310 ms)
# [126/300] Uploading keywords_curated/_unknown/_unknown.0827.wav OK (264 ms)
# [127/300] Uploading keywords_curated/_unknown/_unknown.0381.wav OK (311 ms)
# [128/300] Uploading keywords_curated/_unknown/_unknown.0005.wav OK (325 ms)
# [129/300] Uploading keywords_curated/_unknown/_unknown.1082.wav OK (387 ms)
# [130/300] Uploading keywords_curated/_unknown/_unknown.1210.wav OK (275 ms)
# [131/300] Uploading keywords_curated/_unknown/_unknown.0033.wav OK (311 ms)
# [132/300] Uploading keywords_curated/_unknown/_unknown.1461.wav OK (280 ms)
# [133/300] Uploading keywords_curated/_unknown/_unknown.0963.wav OK (262 ms)
# [134/300] Uploading keywords_curated/_unknown/_unknown.0142.wav OK (330 ms)
# [135/300] Uploading keywords_curated/_unknown/_unknown.0999.wav OK (387 ms)
# [136/300] Uploading keywords_curated/_unknown/_unknown.0703.wav OK (437 ms)
# [137/300] Uploading keywords_curated/_unknown/_unknown.0569.wav OK (454 ms)
# [138/300] Uploading keywords_curated/_unknown/_unknown.0157.wav OK (502 ms)
# [139/300] Uploading keywords_curated/_unknown/_unknown.1268.wav OK (272 ms)
# [140/300] Uploading keywords_curated/_unknown/_unknown.1457.wav OK (289 ms)
# [141/300] Uploading keywords_curated/_unknown/_unknown.1011.wav OK (384 ms)
# [142/300] Uploading keywords_curated/_unknown/_unknown.1114.wav OK (294 ms)
# [143/300] Uploading keywords_curated/_unknown/_unknown.0163.wav OK (319 ms)
# [144/300] Uploading keywords_curated/_unknown/_unknown.0341.wav OK (246 ms)
# [145/300] Uploading keywords_curated/_unknown/_unknown.0173.wav OK (278 ms)
# [146/300] Uploading keywords_curated/_unknown/_unknown.0043.wav OK (270 ms)
# [147/300] Uploading keywords_curated/_unknown/_unknown.1179.wav OK (309 ms)
# [148/300] Uploading keywords_curated/_unknown/_unknown.0738.wav OK (292 ms)
# [149/300] Uploading keywords_curated/_unknown/_unknown.1000.wav OK (309 ms)
# [150/300] Uploading keywords_curated/_unknown/_unknown.0110.wav OK (401 ms)
# [151/300] Uploading keywords_curated/_unknown/_unknown.0352.wav OK (277 ms)
# [152/300] Uploading keywords_curated/_unknown/_unknown.1404.wav OK (294 ms)
# [153/300] Uploading keywords_curated/_unknown/_unknown.1409.wav OK (263 ms)
# [154/300] Uploading keywords_curated/_unknown/_unknown.1172.wav OK (327 ms)
# [155/300] Uploading keywords_curated/_unknown/_unknown.0044.wav OK (310 ms)
# [156/300] Uploading keywords_curated/_unknown/_unknown.1238.wav OK (249 ms)
# [157/300] Uploading keywords_curated/_unknown/_unknown.0713.wav OK (264 ms)
# [158/300] Uploading keywords_curated/_unknown/_unknown.1105.wav OK (332 ms)
# [159/300] Uploading keywords_curated/_unknown/_unknown.1447.wav OK (318 ms)
# [160/300] Uploading keywords_curated/_unknown/_unknown.0329.wav OK (289 ms)
# [161/300] Uploading keywords_curated/_unknown/_unknown.0180.wav OK (258 ms)
# [162/300] Uploading keywords_curated/_unknown/_unknown.0303.wav OK (312 ms)
# [163/300] Uploading keywords_curated/_unknown/_unknown.1239.wav OK (263 ms)
# [164/300] Uploading keywords_curated/_unknown/_unknown.0497.wav OK (281 ms)
# [165/300] Uploading keywords_curated/_unknown/_unknown.1396.wav OK (279 ms)
# [166/300] Uploading keywords_curated/_unknown/_unknown.0724.wav OK (260 ms)
# [167/300] Uploading keywords_curated/_unknown/_unknown.0824.wav OK (262 ms)
# [168/300] Uploading keywords_curated/_unknown/_unknown.0038.wav OK (443 ms)
# [169/300] Uploading keywords_curated/_unknown/_unknown.0075.wav OK (313 ms)
# [170/300] Uploading keywords_curated/_unknown/_unknown.0483.wav OK (282 ms)
# [171/300] Uploading keywords_curated/_unknown/_unknown.0421.wav OK (251 ms)
# [172/300] Uploading keywords_curated/_unknown/_unknown.0298.wav OK (233 ms)
# [173/300] Uploading keywords_curated/_unknown/_unknown.1081.wav OK (216 ms)
# [174/300] Uploading keywords_curated/_unknown/_unknown.1117.wav OK (467 ms)
# [175/300] Uploading keywords_curated/_unknown/_unknown.0065.wav OK (302 ms)
# [176/300] Uploading keywords_curated/_unknown/_unknown.1283.wav OK (318 ms)
# [177/300] Uploading keywords_curated/_unknown/_unknown.1243.wav OK (396 ms)
# [178/300] Uploading keywords_curated/_unknown/_unknown.0870.wav OK (245 ms)
# [179/300] Uploading keywords_curated/_unknown/_unknown.0832.wav OK (245 ms)
# [180/300] Uploading keywords_curated/_unknown/_unknown.1257.wav OK (458 ms)
# [181/300] Uploading keywords_curated/_unknown/_unknown.0848.wav OK (289 ms)
# [182/300] Uploading keywords_curated/_unknown/_unknown.1468.wav OK (252 ms)
# [183/300] Uploading keywords_curated/_unknown/_unknown.0404.wav OK (260 ms)
# [184/300] Uploading keywords_curated/_unknown/_unknown.1196.wav OK (449 ms)
# [185/300] Uploading keywords_curated/_unknown/_unknown.0226.wav OK (260 ms)
# [186/300] Uploading keywords_curated/_unknown/_unknown.0819.wav OK (417 ms)
# [187/300] Uploading keywords_curated/_unknown/_unknown.1124.wav OK (244 ms)
# [188/300] Uploading keywords_curated/_unknown/_unknown.0383.wav OK (260 ms)
# [189/300] Uploading keywords_curated/_unknown/_unknown.0928.wav OK (447 ms)
# [190/300] Uploading keywords_curated/_unknown/_unknown.0503.wav OK (281 ms)
# [191/300] Uploading keywords_curated/_unknown/_unknown.0462.wav OK (261 ms)
# [192/300] Uploading keywords_curated/_unknown/_unknown.1310.wav OK (320 ms)
# [193/300] Uploading keywords_curated/_unknown/_unknown.0601.wav OK (290 ms)
# [194/300] Uploading keywords_curated/_unknown/_unknown.1465.wav OK (272 ms)
# [195/300] Uploading keywords_curated/_unknown/_unknown.0029.wav OK (442 ms)
# [196/300] Uploading keywords_curated/_unknown/_unknown.1115.wav OK (259 ms)
# [197/300] Uploading keywords_curated/_unknown/_unknown.0141.wav OK (409 ms)
# [198/300] Uploading keywords_curated/_unknown/_unknown.0013.wav OK (285 ms)
# [199/300] Uploading keywords_curated/_unknown/_unknown.0548.wav OK (312 ms)
# [200/300] Uploading keywords_curated/_unknown/_unknown.0757.wav OK (268 ms)
# ...
# [ 985/1200] Uploading keywords_curated/marvin/marvin.1386.wav OK (387 ms)
# [ 986/1200] Uploading keywords_curated/marvin/marvin.1460.wav OK (290 ms)
# [ 987/1200] Uploading keywords_curated/marvin/marvin.0992.wav OK (254 ms)
# [ 988/1200] Uploading keywords_curated/marvin/marvin.0703.wav OK (306 ms)
# [ 989/1200] Uploading keywords_curated/marvin/marvin.0991.wav OK (342 ms)
# [ 990/1200] Uploading keywords_curated/marvin/marvin.1373.wav OK (283 ms)
# [ 991/1200] Uploading keywords_curated/marvin/marvin.0720.wav OK (448 ms)
# [ 992/1200] Uploading keywords_curated/marvin/marvin.0630.wav OK (268 ms)
# [ 993/1200] Uploading keywords_curated/marvin/marvin.1399.wav OK (299 ms)
# [ 994/1200] Uploading keywords_curated/marvin/marvin.0849.wav OK (303 ms)
# [ 995/1200] Uploading keywords_curated/marvin/marvin.0985.wav OK (319 ms)
# [ 996/1200] Uploading keywords_curated/marvin/marvin.1472.wav OK (266 ms)
# [ 997/1200] Uploading keywords_curated/marvin/marvin.0808.wav OK (225 ms)
# [ 998/1200] Uploading keywords_curated/marvin/marvin.0812.wav OK (324 ms)
# [ 999/1200] Uploading keywords_curated/marvin/marvin.1291.wav OK (257 ms)
# [1000/1200] Uploading keywords_curated/marvin/marvin.1095.wav OK (391 ms)
# [1001/1200] Uploading keywords_curated/marvin/marvin.0319.wav OK (277 ms)
# [1002/1200] Uploading keywords_curated/marvin/marvin.1396.wav OK (259 ms)
# [1003/1200] Uploading keywords_curated/marvin/marvin.0263.wav OK (244 ms)
# [1004/1200] Uploading keywords_curated/marvin/marvin.0186.wav OK (294 ms)
# [1005/1200] Uploading keywords_curated/marvin/marvin.1307.wav OK (262 ms)
# [1006/1200] Uploading keywords_curated/marvin/marvin.0305.wav OK (280 ms)
# [1007/1200] Uploading keywords_curated/marvin/marvin.1495.wav OK (249 ms)
# [1008/1200] Uploading keywords_curated/marvin/marvin.1159.wav OK (387 ms)
# [1009/1200] Uploading keywords_curated/marvin/marvin.1099.wav OK (319 ms)
# [1010/1200] Uploading keywords_curated/marvin/marvin.1244.wav OK (337 ms)
# [1011/1200] Uploading keywords_curated/marvin/marvin.0022.wav OK (292 ms)
# [1012/1200] Uploading keywords_curated/marvin/marvin.0547.wav OK (308 ms)
# [1013/1200] Uploading keywords_curated/marvin/marvin.0561.wav OK (286 ms)
# [1014/1200] Uploading keywords_curated/marvin/marvin.0653.wav OK (308 ms)
# [1015/1200] Uploading keywords_curated/marvin/marvin.0711.wav OK (1338 ms)
# [1016/1200] Uploading keywords_curated/marvin/marvin.0238.wav OK (324 ms)
# [1017/1200] Uploading keywords_curated/marvin/marvin.0688.wav OK (339 ms)
# [1018/1200] Uploading keywords_curated/marvin/marvin.0841.wav OK (348 ms)
# [1019/1200] Uploading keywords_curated/marvin/marvin.0649.wav OK (327 ms)
# [1020/1200] Uploading keywords_curated/marvin/marvin.0746.wav OK (363 ms)
# [1021/1200] Uploading keywords_curated/marvin/marvin.0018.wav OK (280 ms)
# [1022/1200] Uploading keywords_curated/marvin/marvin.1152.wav OK (300 ms)
# [1023/1200] Uploading keywords_curated/marvin/marvin.1283.wav OK (316 ms)
# [1024/1200] Uploading keywords_curated/marvin/marvin.0534.wav OK (264 ms)
# [1025/1200] Uploading keywords_curated/marvin/marvin.0292.wav OK (231 ms)
# [1026/1200] Uploading keywords_curated/marvin/marvin.0157.wav OK (317 ms)
# [1027/1200] Uploading keywords_curated/marvin/marvin.1471.wav OK (314 ms)
# [1028/1200] Uploading keywords_curated/marvin/marvin.0098.wav OK (291 ms)
# [1029/1200] Uploading keywords_curated/marvin/marvin.0936.wav OK (245 ms)
# [1030/1200] Uploading keywords_curated/marvin/marvin.0277.wav OK (246 ms)
# [1031/1200] Uploading keywords_curated/marvin/marvin.0050.wav OK (410 ms)
# [1032/1200] Uploading keywords_curated/marvin/marvin.1439.wav OK (356 ms)
# [1033/1200] Uploading keywords_curated/marvin/marvin.0934.wav OK (421 ms)
# [1034/1200] Uploading keywords_curated/marvin/marvin.0294.wav OK (390 ms)
# [1035/1200] Uploading keywords_curated/marvin/marvin.0868.wav OK (259 ms)
# [1036/1200] Uploading keywords_curated/marvin/marvin.1330.wav OK (311 ms)
# [1037/1200] Uploading keywords_curated/marvin/marvin.0520.wav OK (294 ms)
# [1038/1200] Uploading keywords_curated/marvin/marvin.1355.wav OK (293 ms)
# [1039/1200] Uploading keywords_curated/marvin/marvin.0187.wav OK (263 ms)
# [1040/1200] Uploading keywords_curated/marvin/marvin.0616.wav OK (245 ms)
# [1041/1200] Uploading keywords_curated/marvin/marvin.1255.wav OK (223 ms)
# [1042/1200] Uploading keywords_curated/marvin/marvin.0584.wav OK (450 ms)
# [1043/1200] Uploading keywords_curated/marvin/marvin.1411.wav OK (236 ms)
# [1044/1200] Uploading keywords_curated/marvin/marvin.1261.wav OK (469 ms)
# [1045/1200] Uploading keywords_curated/marvin/marvin.1157.wav OK (313 ms)
# [1046/1200] Uploading keywords_curated/marvin/marvin.0260.wav OK (249 ms)
# [1047/1200] Uploading keywords_curated/marvin/marvin.0242.wav OK (397 ms)
# [1048/1200] Uploading keywords_curated/marvin/marvin.0254.wav OK (307 ms)
# [1049/1200] Uploading keywords_curated/marvin/marvin.0644.wav OK (254 ms)
# [1050/1200] Uploading keywords_curated/marvin/marvin.0967.wav OK (273 ms)
# [1051/1200] Uploading keywords_curated/marvin/marvin.0423.wav OK (454 ms)
# [1052/1200] Uploading keywords_curated/marvin/marvin.0189.wav OK (366 ms)
# [1053/1200] Uploading keywords_curated/marvin/marvin.0663.wav OK (627 ms)
# [1054/1200] Uploading keywords_curated/marvin/marvin.0384.wav OK (288 ms)
# [1055/1200] Uploading keywords_curated/marvin/marvin.0336.wav OK (266 ms)
# [1056/1200] Uploading keywords_curated/marvin/marvin.1464.wav OK (306 ms)
# [1057/1200] Uploading keywords_curated/marvin/marvin.1124.wav OK (291 ms)
# [1058/1200] Uploading keywords_curated/marvin/marvin.1345.wav OK (273 ms)
# [1059/1200] Uploading keywords_curated/marvin/marvin.0262.wav OK (304 ms)
# [1060/1200] Uploading keywords_curated/marvin/marvin.1250.wav OK (271 ms)
# [1061/1200] Uploading keywords_curated/marvin/marvin.1343.wav OK (289 ms)
# [1062/1200] Uploading keywords_curated/marvin/marvin.0362.wav OK (237 ms)
# [1063/1200] Uploading keywords_curated/marvin/marvin.0858.wav OK (304 ms)
# [1064/1200] Uploading keywords_curated/marvin/marvin.1446.wav OK (233 ms)
# [1065/1200] Uploading keywords_curated/marvin/marvin.0233.wav OK (283 ms)
# [1066/1200] Uploading keywords_curated/marvin/marvin.1109.wav OK (266 ms)
# [1067/1200] Uploading keywords_curated/marvin/marvin.0564.wav OK (235 ms)
# [1068/1200] Uploading keywords_curated/marvin/marvin.1241.wav OK (251 ms)
# [1069/1200] Uploading keywords_curated/marvin/marvin.0009.wav OK (326 ms)
# [1070/1200] Uploading keywords_curated/marvin/marvin.0595.wav OK (456 ms)
# [1071/1200] Uploading keywords_curated/marvin/marvin.0560.wav OK (300 ms)
# [1072/1200] Uploading keywords_curated/marvin/marvin.0681.wav OK (256 ms)
# [1073/1200] Uploading keywords_curated/marvin/marvin.0143.wav OK (316 ms)
# [1074/1200] Uploading keywords_curated/marvin/marvin.0445.wav OK (306 ms)
# [1075/1200] Uploading keywords_curated/marvin/marvin.0138.wav OK (273 ms)
# [1076/1200] Uploading keywords_curated/marvin/marvin.0101.wav OK (291 ms)
# [1077/1200] Uploading keywords_curated/marvin/marvin.0396.wav OK (288 ms)
# [1078/1200] Uploading keywords_curated/marvin/marvin.0060.wav OK (257 ms)
# [1079/1200] Uploading keywords_curated/marvin/marvin.1498.wav OK (291 ms)
# [1080/1200] Uploading keywords_curated/marvin/marvin.0863.wav OK (307 ms)
# [1081/1200] Uploading keywords_curated/marvin/marvin.0930.wav OK (435 ms)
# [1082/1200] Uploading keywords_curated/marvin/marvin.1270.wav OK (292 ms)
# [1083/1200] Uploading keywords_curated/marvin/marvin.0313.wav OK (397 ms)
# [1084/1200] Uploading keywords_curated/marvin/marvin.0370.wav OK (232 ms)
# [1085/1200] Uploading keywords_curated/marvin/marvin.0014.wav OK (286 ms)
# [1086/1200] Uploading keywords_curated/marvin/marvin.0039.wav OK (301 ms)
# [1087/1200] Uploading keywords_curated/marvin/marvin.0372.wav OK (274 ms)
# [1088/1200] Uploading keywords_curated/marvin/marvin.1454.wav OK (335 ms)
# [1089/1200] Uploading keywords_curated/marvin/marvin.0080.wav OK (266 ms)
# [1090/1200] Uploading keywords_curated/marvin/marvin.0375.wav OK (217 ms)
# [1091/1200] Uploading keywords_curated/marvin/marvin.0337.wav OK (433 ms)
# [1092/1200] Uploading keywords_curated/marvin/marvin.0766.wav OK (285 ms)
# [1093/1200] Uploading keywords_curated/marvin/marvin.1191.wav OK (269 ms)
# [1094/1200] Uploading keywords_curated/marvin/marvin.0609.wav OK (270 ms)
# [1095/1200] Uploading keywords_curated/marvin/marvin.0502.wav OK (288 ms)
# [1096/1200] Uploading keywords_curated/marvin/marvin.0745.wav OK (253 ms)
# [1097/1200] Uploading keywords_curated/marvin/marvin.0692.wav OK (238 ms)
# [1098/1200] Uploading keywords_curated/marvin/marvin.0010.wav OK (400 ms)
# [1099/1200] Uploading keywords_curated/marvin/marvin.1176.wav OK (231 ms)
# [1100/1200] Uploading keywords_curated/marvin/marvin.1364.wav OK (268 ms)
# [1101/1200] Uploading keywords_curated/marvin/marvin.0402.wav OK (430 ms)
# [1102/1200] Uploading keywords_curated/marvin/marvin.1100.wav OK (290 ms)
# [1103/1200] Uploading keywords_curated/marvin/marvin.0239.wav OK (303 ms)
# [1104/1200] Uploading keywords_curated/marvin/marvin.1118.wav OK (285 ms)
# [1105/1200] Uploading keywords_curated/marvin/marvin.0358.wav OK (299 ms)
# [1106/1200] Uploading keywords_curated/marvin/marvin.1016.wav OK (314 ms)
# [1107/1200] Uploading keywords_curated/marvin/marvin.0530.wav OK (282 ms)
# [1108/1200] Uploading keywords_curated/marvin/marvin.0142.wav OK (263 ms)
# [1109/1200] Uploading keywords_curated/marvin/marvin.0414.wav OK (299 ms)
# [1110/1200] Uploading keywords_curated/marvin/marvin.0872.wav OK (231 ms)
# [1111/1200] Uploading keywords_curated/marvin/marvin.0241.wav OK (278 ms)
# [1112/1200] Uploading keywords_curated/marvin/marvin.1027.wav OK (296 ms)
# [1113/1200] Uploading keywords_curated/marvin/marvin.1042.wav OK (246 ms)
# [1114/1200] Uploading keywords_curated/marvin/marvin.0890.wav OK (324 ms)
# [1115/1200] Uploading keywords_curated/marvin/marvin.1337.wav OK (276 ms)
# [1116/1200] Uploading keywords_curated/marvin/marvin.0704.wav OK (255 ms)
# [1117/1200] Uploading keywords_curated/marvin/marvin.1240.wav OK (266 ms)
# [1118/1200] Uploading keywords_curated/marvin/marvin.0426.wav OK (251 ms)
# [1119/1200] Uploading keywords_curated/marvin/marvin.1218.wav OK (274 ms)
# [1120/1200] Uploading keywords_curated/marvin/marvin.0763.wav OK (278 ms)
# [1121/1200] Uploading keywords_curated/marvin/marvin.1069.wav OK (246 ms)
# [1122/1200] Uploading keywords_curated/marvin/marvin.0786.wav OK (294 ms)
# [1123/1200] Uploading keywords_curated/marvin/marvin.0525.wav OK (488 ms)
# [1124/1200] Uploading keywords_curated/marvin/marvin.0250.wav OK (260 ms)
# [1125/1200] Uploading keywords_curated/marvin/marvin.0135.wav OK (278 ms)
# [1126/1200] Uploading keywords_curated/marvin/marvin.1030.wav OK (229 ms)
# [1127/1200] Uploading keywords_curated/marvin/marvin.0776.wav OK (244 ms)
# [1128/1200] Uploading keywords_curated/marvin/marvin.0538.wav OK (288 ms)
# [1129/1200] Uploading keywords_curated/marvin/marvin.0371.wav OK (304 ms)
# [1130/1200] Uploading keywords_curated/marvin/marvin.0998.wav OK (289 ms)
# [1131/1200] Uploading keywords_curated/marvin/marvin.0796.wav OK (451 ms)
# [1132/1200] Uploading keywords_curated/marvin/marvin.0893.wav OK (257 ms)
# [1133/1200] Uploading keywords_curated/marvin/marvin.1397.wav OK (419 ms)
# [1134/1200] Uploading keywords_curated/marvin/marvin.0557.wav OK (305 ms)
# [1135/1200] Uploading keywords_curated/marvin/marvin.0519.wav OK (243 ms)
# [1136/1200] Uploading keywords_curated/marvin/marvin.1433.wav OK (318 ms)
# [1137/1200] Uploading keywords_curated/marvin/marvin.0404.wav OK (289 ms)
# [1138/1200] Uploading keywords_curated/marvin/marvin.1037.wav OK (242 ms)
# [1139/1200] Uploading keywords_curated/marvin/marvin.0274.wav OK (306 ms)
# [1140/1200] Uploading keywords_curated/marvin/marvin.0257.wav OK (371 ms)
# [1141/1200] Uploading keywords_curated/marvin/marvin.0147.wav OK (231 ms)
# [1142/1200] Uploading keywords_curated/marvin/marvin.1019.wav OK (355 ms)
# [1143/1200] Uploading keywords_curated/marvin/marvin.0901.wav OK (325 ms)
# [1144/1200] Uploading keywords_curated/marvin/marvin.0567.wav OK (291 ms)
# [1145/1200] Uploading keywords_curated/marvin/marvin.0652.wav OK (251 ms)
# [1146/1200] Uploading keywords_curated/marvin/marvin.1414.wav OK (379 ms)
# [1147/1200] Uploading keywords_curated/marvin/marvin.0405.wav OK (288 ms)
# [1148/1200] Uploading keywords_curated/marvin/marvin.0403.wav OK (271 ms)
# [1149/1200] Uploading keywords_curated/marvin/marvin.1455.wav OK (286 ms)
# [1150/1200] Uploading keywords_curated/marvin/marvin.0359.wav OK (308 ms)
# [1151/1200] Uploading keywords_curated/marvin/marvin.0480.wav OK (292 ms)
# [1152/1200] Uploading keywords_curated/marvin/marvin.1477.wav OK (433 ms)
# [1153/1200] Uploading keywords_curated/marvin/marvin.0892.wav OK (241 ms)
# [1154/1200] Uploading keywords_curated/marvin/marvin.0231.wav OK (307 ms)
# [1155/1200] Uploading keywords_curated/marvin/marvin.0678.wav OK (263 ms)
# [1156/1200] Uploading keywords_curated/marvin/marvin.0633.wav OK (294 ms)
# [1157/1200] Uploading keywords_curated/marvin/marvin.0366.wav OK (259 ms)
# [1158/1200] Uploading keywords_curated/marvin/marvin.0178.wav OK (310 ms)
# [1159/1200] Uploading keywords_curated/marvin/marvin.0268.wav OK (326 ms)
# [1160/1200] Uploading keywords_curated/marvin/marvin.1405.wav OK (253 ms)
# [1161/1200] Uploading keywords_curated/marvin/marvin.0300.wav OK (270 ms)
# [1162/1200] Uploading keywords_curated/marvin/marvin.0302.wav OK (293 ms)
# [1163/1200] Uploading keywords_curated/marvin/marvin.0156.wav OK (238 ms)
# [1164/1200] Uploading keywords_curated/marvin/marvin.0185.wav OK (290 ms)
# [1165/1200] Uploading keywords_curated/marvin/marvin.0793.wav OK (239 ms)
# [1166/1200] Uploading keywords_curated/marvin/marvin.0398.wav OK (258 ms)
# [1167/1200] Uploading keywords_curated/marvin/marvin.0515.wav OK (240 ms)
# [1168/1200] Uploading keywords_curated/marvin/marvin.0666.wav OK (288 ms)
# [1169/1200] Uploading keywords_curated/marvin/marvin.0307.wav OK (361 ms)
# [1170/1200] Uploading keywords_curated/marvin/marvin.1363.wav OK (258 ms)
# [1171/1200] Uploading keywords_curated/marvin/marvin.0894.wav OK (306 ms)
# [1172/1200] Uploading keywords_curated/marvin/marvin.0637.wav OK (392 ms)
# [1173/1200] Uploading keywords_curated/marvin/marvin.0744.wav OK (259 ms)
# [1174/1200] Uploading keywords_curated/marvin/marvin.0594.wav OK (276 ms)
# [1175/1200] Uploading keywords_curated/marvin/marvin.0911.wav OK (296 ms)
# [1176/1200] Uploading keywords_curated/marvin/marvin.0860.wav OK (269 ms)
# [1177/1200] Uploading keywords_curated/marvin/marvin.1105.wav OK (252 ms)
# [1178/1200] Uploading keywords_curated/marvin/marvin.0053.wav OK (430 ms)
# [1179/1200] Uploading keywords_curated/marvin/marvin.0647.wav OK (261 ms)
# [1180/1200] Uploading keywords_curated/marvin/marvin.1490.wav OK (277 ms)
# [1181/1200] Uploading keywords_curated/marvin/marvin.0463.wav OK (296 ms)
# [1182/1200] Uploading keywords_curated/marvin/marvin.1188.wav OK (433 ms)
# [1183/1200] Uploading keywords_curated/marvin/marvin.0116.wav OK (243 ms)
# [1184/1200] Uploading keywords_curated/marvin/marvin.1227.wav OK (263 ms)
# [1185/1200] Uploading keywords_curated/marvin/marvin.0803.wav OK (251 ms)
# [1186/1200] Uploading keywords_curated/marvin/marvin.0690.wav OK (260 ms)
# [1187/1200] Uploading keywords_curated/marvin/marvin.0267.wav OK (230 ms)
# [1188/1200] Uploading keywords_curated/marvin/marvin.0334.wav OK (429 ms)
# [1189/1200] Uploading keywords_curated/marvin/marvin.0685.wav OK (242 ms)
# [1190/1200] Uploading keywords_curated/marvin/marvin.0556.wav OK (250 ms)
# [1191/1200] Uploading keywords_curated/marvin/marvin.1002.wav OK (260 ms)
# [1192/1200] Uploading keywords_curated/marvin/marvin.0047.wav OK (252 ms)
# [1193/1200] Uploading keywords_curated/marvin/marvin.0575.wav OK (226 ms)
# [1194/1200] Uploading keywords_curated/marvin/marvin.1087.wav OK (349 ms)
# [1195/1200] Uploading keywords_curated/marvin/marvin.1127.wav OK (250 ms)
# [1196/1200] Uploading keywords_curated/marvin/marvin.0252.wav OK (212 ms)
# [1197/1200] Uploading keywords_curated/marvin/marvin.0544.wav OK (253 ms)
# [1198/1200] Uploading keywords_curated/marvin/marvin.0296.wav OK (276 ms)
# [1199/1200] Uploading keywords_curated/marvin/marvin.0670.wav OK (224 ms)
# [1200/1200] Uploading keywords_curated/marvin/marvin.0256.wav OK (242 ms)
